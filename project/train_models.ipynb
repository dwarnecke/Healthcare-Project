# %%
# Import the drive directory
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Suicide Model"

import torch
import torch.nn as nn
from project.models.classifier import SuicideClassifier
from project.utilities.optimize import train_model
from project.utilities.datasets import SuicidalDataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Suicide Model

# %%
# Load the training and validation data
dataset_train = SuicidalDataset('project/datasets/training_data.csv')
dataset_valid = SuicidalDataset('project/datasets/validation_data.csv')
data = {'train': dataset_train, 'valid': dataset_valid}

# %%
# Train a suicidal notes classifier
model = SuicideClassifier(classes=2, dim=128, transformers=1, linears=1, heads=2)
model = train_model(model, datasets=data, learning_rate=2**-12, batch_size=512, score=0.65)
torch.save(model, 'project/archive/classifier-200e-128d-67f.pth')
# Out:
# Training the model over many epochs...
# Epoch 1 — train/loss 0.0985 ; train/acc 0.9654 ; train/f1 0.6071 ; valid/loss 0.0957 ; valid/acc 0.9646 ; valid/f1 0.5952
# Epoch 2 — train/loss 0.0881 ; train/acc 0.9693 ; train/f1 0.6652 ; valid/loss 0.0991 ; valid/acc 0.9649 ; valid/f1 0.5993
# Epoch 3 — train/loss 0.0927 ; train/acc 0.9698 ; train/f1 0.6774 ; valid/loss 0.0836 ; valid/acc 0.9645 ; valid/f1 0.5915
# Epoch 4 — train/loss 0.0864 ; train/acc 0.9667 ; train/f1 0.7012 ; valid/loss 0.1063 ; valid/acc 0.9638 ; valid/f1 0.6384
# Epoch 5 — train/loss 0.0814 ; train/acc 0.9701 ; train/f1 0.6937 ; valid/loss 0.0960 ; valid/acc 0.9638 ; valid/f1 0.6061
# Epoch 6 — train/loss 0.0784 ; train/acc 0.9727 ; train/f1 0.7354 ; valid/loss 0.1108 ; valid/acc 0.9619 ; valid/f1 0.6239
# Epoch 7 — train/loss 0.0780 ; train/acc 0.9756 ; train/f1 0.7510 ; valid/loss 0.0989 ; valid/acc 0.9652 ; valid/f1 0.6404
# ...
